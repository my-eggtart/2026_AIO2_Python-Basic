# %%
import sys
print("Hello, Python!")
print("Python 버전:"
, sys.version)
print("실행 파일:"
, sys.executable)
# Out:
# Hello, Python!
# Python 버전: 3.13.15 (tags/v3.13.15:4061bc4, Aug  5 2026, 13:05:39) [MSC v.1944 64 bit (AMD64)]
# 실행 파일: c:\study\python-basic\.venv\Scripts\python.exe

# %%
#변수 선언
name = "홍길동"
# print(1)
# print(2)
# print(3)

# %%
fruits = ["사과", "바나나", "포도"]
for fruit in fruits:
    print(fruit)
# Out:
# 사과
# 바나나
# 포도

# %%
for i in range(3): #range(a,b,step) 이때 b는 포함하지 않는다.
    print(i)
# Out:
# 0
# 1
# 2

# %%
user_input = ' '
while user_input != "exit":
    user_input = input("원하는 과자를 입력하세요. 끝내시려면 exit을 입력합니다 ")
    print(user_input)
# Out:
# 빼빼로
# 계란과자
# 강냉이
# 포카칩
# 빈츠
# exit

# %%
print()

# %%
def add(a, b):
    return a + b    
print(add(3, 5))
# Out:
# 8

# %%
def add_int(a, b):
    hap = a + b
    return hap

# %%
from datetime import datetime
current_time = datetime.now()
print(current_time.strftime("%Y-%m-%d %H:%M:%S"))  # 
현재 날짜와 시간 출력
# Out:
#   Cell In[5], line 4
#     현재 날짜와 시간 출력
#        ^
# SyntaxError: invalid syntax
